# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
from sklearn.model_selection import learning_curve
from sklearn.cluster import KMeans

# supress scientific notation
np.set_printoptions(suppress=True)

import wrangle
import viz

import warnings
warnings.filterwarnings("ignore")

# %%
df = wrangle.wrangle_zillow()

# %%
df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0  14297519          3.5         4.0                        3100.0  6059.0
# 1  17052889          1.0         2.0                        1465.0  6111.0
# 2  14186244          2.0         3.0                        1243.0  6059.0
# 3  12177905          3.0         4.0                        2376.0  6037.0
# 6  12095076          3.0         4.0                        2962.0  6037.0
#
#      latitude    longitude  regionidcity  regionidcounty  regionidzip  ...  \
# 0  33634931.0 -117869207.0       53571.0          1286.0      96978.0  ...
# 1  34449266.0 -119281531.0       13091.0          2061.0      97099.0  ...
# 2  33886168.0 -117823170.0       21412.0          1286.0      97078.0  ...
# 3  34245180.0 -118240722.0      396551.0          3101.0      96330.0  ...
# 6  34145202.0 -118179824.0       47019.0          3101.0      96293.0  ...
#
#    taxvaluedollarcnt  landtaxvaluedollarcnt  taxamount  logerror  \
# 0          1023282.0               537569.0   11013.72  0.025595
# 1           464000.0               376000.0    5672.48  0.055619
# 2           564778.0               479489.0    6488.30  0.005383
# 3           145143.0                36225.0    1777.51 -0.103410
# 6           773303.0               496619.0    9516.26 -0.001011
#
#    transactiondate     acres   age  dollar_per_sqft  dollar_per_acre  \
# 0       2017-01-01  0.103444  19.0       156.681613     5.196739e+06
# 1       2017-01-01  0.290335  50.0        60.068259     1.295055e+06
# 2       2017-01-01  0.193572  55.0        68.615447     2.477057e+06
# 3       2017-01-01  0.299311  47.0        45.840909     1.210278e+05
# 6       2017-01-01  1.446281  67.0        93.411209     3.433766e+05
#
#         county
# 0       Orange
# 1      Ventura
# 2       Orange
# 3  Los_Angeles
# 6  Los_Angeles
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46763 entries, 0 to 77573
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      46763 non-null  int64
#  1   bathroomcnt                   46763 non-null  float64
#  2   bedroomcnt                    46763 non-null  float64
#  3   calculatedfinishedsquarefeet  46763 non-null  float64
#  4   fips                          46763 non-null  float64
#  5   latitude                      46763 non-null  float64
#  6   longitude                     46763 non-null  float64
#  7   regionidcity                  46763 non-null  float64
#  8   regionidcounty                46763 non-null  float64
#  9   regionidzip                   46763 non-null  float64
#  10  structuretaxvaluedollarcnt    46763 non-null  float64
#  11  taxvaluedollarcnt             46763 non-null  float64
#  12  landtaxvaluedollarcnt         46763 non-null  float64
#  13  taxamount                     46763 non-null  float64
#  14  logerror                      46763 non-null  float64
#  15  transactiondate               46763 non-null  object
#  16  acres                         46763 non-null  float64
#  17  age                           46763 non-null  float64
#  18  dollar_per_sqft               46763 non-null  float64
#  19  dollar_per_acre               46763 non-null  float64
#  20  county                        46763 non-null  object
# dtypes: float64(18), int64(1), object(2)
# memory usage: 7.8+ MB

# %%
sns.boxplot(data = df)
# Out:
# <AxesSubplot:>

# %%
df.drop(columns = ['parcelid', 'county', 'transactiondate'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46763 entries, 0 to 77573
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   bathroomcnt                   46763 non-null  float64
#  1   bedroomcnt                    46763 non-null  float64
#  2   calculatedfinishedsquarefeet  46763 non-null  float64
#  3   fips                          46763 non-null  float64
#  4   latitude                      46763 non-null  float64
#  5   longitude                     46763 non-null  float64
#  6   regionidcity                  46763 non-null  float64
#  7   regionidcounty                46763 non-null  float64
#  8   regionidzip                   46763 non-null  float64
#  9   structuretaxvaluedollarcnt    46763 non-null  float64
#  10  taxvaluedollarcnt             46763 non-null  float64
#  11  landtaxvaluedollarcnt         46763 non-null  float64
#  12  taxamount                     46763 non-null  float64
#  13  logerror                      46763 non-null  float64
#  14  acres                         46763 non-null  float64
#  15  age                           46763 non-null  float64
#  16  dollar_per_sqft               46763 non-null  float64
#  17  dollar_per_acre               46763 non-null  float64
# dtypes: float64(18)
# memory usage: 6.8 MB

# %%
viz.features_outliers(df)

# %%
df.describe().T
# Out:
#                                 count          mean           std  \
# bathroomcnt                   46763.0  2.141458e+00  7.944417e-01
# bedroomcnt                    46763.0  3.230161e+00  8.690854e-01
# calculatedfinishedsquarefeet  46763.0  1.739177e+03  6.728621e+02
# fips                          46763.0  6.049283e+03  2.125570e+01
# latitude                      46763.0  3.402485e+07  2.720829e+05
# longitude                     46763.0 -1.181902e+08  3.546282e+05
# regionidcity                  46763.0  3.397859e+04  5.080947e+04
# regionidcounty                46763.0  2.525255e+03  8.024189e+02
# regionidzip                   46763.0  9.657344e+04  4.215741e+02
# structuretaxvaluedollarcnt    46763.0  1.479262e+05  1.056011e+05
# taxvaluedollarcnt             46763.0  3.896143e+05  2.689702e+05
# landtaxvaluedollarcnt         46763.0  2.416881e+05  2.053501e+05
# taxamount                     46763.0  4.805662e+03  3.051068e+03
# logerror                      46763.0  1.709335e-02  1.675763e-01
# acres                         46763.0  1.814959e-01  1.305084e-01
# age                           46763.0  5.501041e+01  2.207399e+01
# dollar_per_sqft               46763.0  8.187795e+01  4.183209e+01
# dollar_per_acre               46763.0  1.764547e+06  2.032398e+06
#
#                                        min           25%           50%  \
# bathroomcnt                   1.000000e+00  2.000000e+00  2.000000e+00
# bedroomcnt                    1.000000e+00  3.000000e+00  3.000000e+00
# calculatedfinishedsquarefeet  3.600000e+02  1.241000e+03  1.588000e+03
# fips                          6.037000e+03  6.037000e+03  6.037000e+03
# latitude                      3.334062e+07  3.383091e+07  3.401523e+07
# longitude                    -1.194753e+08 -1.183849e+08 -1.181432e+08
# regionidcity                  3.491000e+03  1.244700e+04  2.481200e+04
# regionidcounty                1.286000e+03  1.286000e+03  3.101000e+03
# regionidzip                   9.598200e+04  9.621200e+04  9.642400e+04
# structuretaxvaluedollarcnt    1.480000e+02  7.282800e+04  1.210000e+05
# taxvaluedollarcnt             3.254000e+03  1.772805e+05  3.423580e+05
# landtaxvaluedollarcnt         1.610000e+02  6.521500e+04  1.959820e+05
# taxamount                     4.918000e+01  2.477695e+03  4.296500e+03
# logerror                     -4.655420e+00 -2.465472e-02  6.154649e-03
# acres                         5.417815e-03  1.262626e-01  1.540174e-01
# age                           1.000000e+00  4.000000e+01  5.700000e+01
# dollar_per_sqft               1.582809e-01  5.227837e+01  7.801731e+01
# dollar_per_acre               1.316778e+02  3.750445e+05  1.237411e+06
#
#                                        75%           max
# bathroomcnt                   3.000000e+00  7.000000e+00
# bedroomcnt                    4.000000e+00  7.000000e+00
# calculatedfinishedsquarefeet  2.114000e+03  3.998000e+03
# fips                          6.059000e+03  6.111000e+03
# latitude                      3.419078e+07  3.475508e+07
# longitude                    -1.179326e+08 -1.175723e+08
# regionidcity                  4.022700e+04  3.965560e+05
# regionidcounty                3.101000e+03  3.101000e+03
# regionidzip                   9.700100e+04  9.734400e+04
# structuretaxvaluedollarcnt    1.939485e+05  9.552760e+05
# taxvaluedollarcnt             5.392850e+05  1.974661e+06
# landtaxvaluedollarcnt         3.595375e+05  1.786325e+06
# taxamount                     6.451720e+03  1.499888e+04
# logerror                      3.808163e-02  3.175688e+00
# acres                         1.891644e-01  1.493067e+00
# age                           6.700000e+01  1.390000e+02
# dollar_per_sqft               1.057711e+02  8.159333e+02
# dollar_per_acre               2.377757e+06  3.563411e+07

# %%
# df = df[df.fips == 6059]

# %%
df.sample(25)
# Out:
#        bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 40086          3.0         4.0                        2476.0  6059.0
# 10723          2.0         3.0                        1600.0  6037.0
# 74247          2.0         3.0                        1357.0  6037.0
# 8292           3.0         4.0                        2484.0  6037.0
# 10878          2.0         3.0                        3427.0  6037.0
# 18538          2.5         3.0                        1768.0  6059.0
# 65655          2.0         3.0                        1570.0  6037.0
# 28172          2.0         3.0                        1083.0  6059.0
# 54147          2.0         3.0                        1626.0  6037.0
# 69023          1.0         3.0                        1210.0  6037.0
# 37611          1.5         3.0                        1512.0  6059.0
# 30082          3.0         4.0                        2278.0  6059.0
# 11600          2.0         3.0                        1346.0  6037.0
# 27156          3.0         5.0                        2496.0  6059.0
# 69999          3.0         5.0                        2289.0  6037.0
# 43480          2.0         2.0                        1619.0  6037.0
# 20266          2.5         3.0                        2104.0  6059.0
# 10424          3.0         5.0                        2388.0  6037.0
# 50397          3.0         3.0                        1933.0  6059.0
# 33545          1.0         2.0                        1026.0  6037.0
# 60651          2.0         4.0                        1814.0  6059.0
# 48541          4.0         3.0                        1906.0  6037.0
# 21824          3.0         3.0                        1680.0  6037.0
# 70223          2.0         4.0                        1204.0  6037.0
# 73551          2.0         3.0                        1770.0  6037.0
#
#          latitude    longitude  regionidcity  regionidcounty  regionidzip  \
# 40086  33649905.0 -117898472.0       38032.0          1286.0      96959.0
# 10723  34065379.0 -117796704.0       20008.0          3101.0      96508.0
# 74247  33897936.0 -118082219.0       53636.0          3101.0      96193.0
# 8292   34034760.0 -117827592.0       34636.0          3101.0      96522.0
# 10878  34643891.0 -118249415.0       40227.0          3101.0      97329.0
# 18538  33486948.0 -117681009.0       33840.0          1286.0      96985.0
# 65655  34261552.0 -118494056.0       12447.0          3101.0      96370.0
# 28172  33652107.0 -117590163.0       15554.0          1286.0      96993.0
# 54147  34004381.0 -117884130.0       14542.0          3101.0      96525.0
# 69023  33842223.0 -118152717.0       12292.0          3101.0      96212.0
# 37611  33810261.0 -118020387.0       10608.0          1286.0      96180.0
# 30082  33883668.0 -117768570.0       21412.0          1286.0      97079.0
# 11600  33934773.0 -117976019.0       18874.0          3101.0      96171.0
# 27156  33527809.0 -117619727.0       15554.0          1286.0      96998.0
# 69999  34394241.0 -118543977.0       54311.0          3101.0      96378.0
# 43480  33869543.0 -118197703.0       46298.0          3101.0      96239.0
# 20266  33650962.0 -117902568.0       38032.0          1286.0      96959.0
# 10424  33822574.0 -118338344.0       54722.0          3101.0      96163.0
# 50397  33796814.0 -118014854.0       44833.0          1286.0      96185.0
# 33545  34179325.0 -118142678.0       47019.0          3101.0      96292.0
# 60651  33879679.0 -117942404.0       24812.0          1286.0      97041.0
# 48541  34179181.0 -118282477.0       45457.0          3101.0      96320.0
# 21824  33954491.0 -118118529.0        4406.0          3101.0      96100.0
# 70223  33864296.0 -118344605.0       54722.0          3101.0      96162.0
# 73551  34095210.0 -118037384.0       14111.0          3101.0      96517.0
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 40086                    373594.0          1035457.0               661863.0
# 10723                     97870.0           190548.0                92678.0
# 74247                     44546.0            63364.0                18818.0
# 8292                     320561.0           575097.0               254536.0
# 10878                    296600.0           396000.0                99400.0
# 18538                    169515.0           377238.0               207723.0
# 65655                     49891.0            66433.0                16542.0
# 28172                    106788.0           502234.0               395446.0
# 54147                     82842.0           414212.0               331370.0
# 69023                     97000.0           491000.0               394000.0
# 37611                     89342.0           254277.0               164935.0
# 30082                    235647.0           340287.0               104640.0
# 11600                    105999.0           343276.0               237277.0
# 27156                    421080.0           753213.0               332133.0
# 69999                    262000.0           550000.0               288000.0
# 43480                     42846.0            60217.0                17371.0
# 20266                    279336.0           634973.0               355637.0
# 10424                     79094.0           142654.0                63560.0
# 50397                    137419.0           478507.0               341088.0
# 33545                     28187.0            44112.0                15925.0
# 60651                    106986.0           556671.0               449685.0
# 48541                    341929.0           710063.0               368134.0
# 21824                    208923.0           451768.0               242845.0
# 70223                     74869.0           305732.0               230863.0
# 73551                     51754.0            70572.0                18818.0
#
#        taxamount  logerror     acres    age  dollar_per_sqft  dollar_per_acre
# 40086   11448.08 -0.007811  0.154959   12.0       150.886107     4.271223e+06
# 10723    2544.45  0.028375  0.183356   32.0        61.168750     5.054531e+05
# 74247    1104.31 -0.002543  0.133907   67.0        32.826824     1.405301e+05
# 8292     6942.29 -0.036281  0.220271   29.0       129.050322     1.155559e+06
# 10878    6357.07  0.143022  0.230005   11.0        86.548001     4.321653e+05
# 18538    3897.58 -0.001051  0.097934   19.0        95.879525     2.121053e+06
# 65655     935.21  0.030937  0.180670   57.0        31.777707     9.155902e+04
# 28172    6916.18 -0.013154  0.082645   30.0        98.603878     4.784897e+06
# 54147    5176.83  0.017509  0.141896   48.0        50.948339     2.335298e+06
# 69023    6014.48 -0.066588  0.117080   65.0        80.165289     3.365224e+06
# 37611    3062.14  0.875062  0.156061   59.0        59.088624     1.056865e+06
# 30082    4335.12 -0.226730  0.390266   34.0       103.444688     2.681246e+05
# 11600    3855.49  0.003031  0.249334   61.0        78.751114     9.516422e+05
# 27156   12184.24 -0.004524  0.084711    3.0       168.701923     3.920790e+06
# 69999    7446.63  0.004348  0.122337   46.0       114.460463     2.354153e+06
# 43480     894.15  0.170791  0.107002   77.0        26.464484     1.623430e+05
# 20266    7318.22  0.026668  0.066001   20.0       132.764259     5.388364e+06
# 10424    1837.27 -0.078526  0.140060   54.0        33.121441     4.538065e+05
# 50397    5500.28 -0.019730  0.059688   42.0        71.091050     5.714536e+06
# 33545     735.11 -0.079404  0.169146  101.0        27.472710     9.414943e+04
# 60651    6300.70 -0.028805  0.291483   50.0        58.977949     1.542749e+06
# 48541    7747.10  0.064236  0.172750   85.0       179.396118     2.131019e+06
# 21824    5514.06 -0.007416  0.169215   62.0       124.358929     1.435128e+06
# 70223    3597.72 -0.024720  0.122957   63.0        62.183555     1.877594e+06
# 73551    1302.20 -0.022412  0.114578   63.0        29.239548     1.642380e+05

# %%
# split data
train, validate, test = wrangle.split_data(df)

# %%
train.head()
# Out:
#        bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 58664          2.0         4.0                        1835.0  6037.0
# 58627          2.5         4.0                        2774.0  6059.0
# 4891           2.0         3.0                        1166.0  6111.0
# 75490          3.0         4.0                        2504.0  6059.0
# 58604          2.0         3.0                        1387.0  6037.0
#
#          latitude    longitude  regionidcity  regionidcounty  regionidzip  \
# 58664  33904380.0 -118136532.0       44116.0          3101.0      96208.0
# 58627  33901728.0 -117853081.0       26531.0          1286.0      97068.0
# 4891   34219641.0 -119162221.0       13150.0          2061.0      97107.0
# 75490  33739429.0 -118000792.0       34780.0          1286.0      96990.0
# 58604  34199981.0 -118418291.0       12447.0          3101.0      96450.0
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 58664                     36225.0            60433.0                24208.0
# 58627                    150328.0           323045.0               172717.0
# 4891                     136169.0           226946.0                90777.0
# 75490                     83899.0           113820.0                29921.0
# 58604                    206302.0           327117.0               120815.0
#
#        taxamount  logerror     acres   age  dollar_per_sqft  dollar_per_acre
# 58664    1049.48  0.009815  0.164922  67.0        19.741144    146784.587973
# 58627    4063.56  0.078906  0.243802  54.0        54.191781    708432.440678
# 4891     2545.40  0.014183  0.137006  55.0       116.783019    662574.752011
# 75490    1771.68  0.009918  0.150826  50.0        33.505990    198380.328767
# 58604    4105.62 -0.037152  0.160514  62.0       148.739726    752674.685355

# %%
# perpective o the county that creates the largest log error 
viz.log_error_by_fip(train)
# Out:
# <AxesSubplot:xlabel='fips', ylabel='logerror'>

# %%
train.groupby('fips').logerror.mean()
# Out:
# fips
# 6037.0    0.016064
# 6059.0    0.024009
# 6111.0    0.011487
# Name: logerror, dtype: float64

# %%
sns.boxplot(data = train, x = 'logerror')
# Out:
# <AxesSubplot:xlabel='logerror'>

# %%
# DAta map based on longitude and latitude
viz.data_map(train)

# %%
# scale data
scaler, train_scaled, validate_scaled, test_scaled = wrangle.min_max_scaler(train, validate, test)

# %%
print(train_scaled.shape)
print(validate_scaled.shape)
print(test_scaled.shape)
# Out:
# (26187, 18)
# (11223, 18)
# (9353, 18)

# %% [markdown]
# ## Ask questions
# - What can we cluster?
#     - bed/bath/sqft
#     - lat/long/age/fips/acres
#     - structuretax/taxvaluedollar/landtax/taxamount/acres
#     - acres/sqft
#     - bed/bath/taxvalue
# - What drives logerror?
#     - Bed/bath/sqft Clusters on logerror
#     - Bed on logerror
#     - bath on logerror
#     - sqft on logerror
#     - fips on logerror

# %% [markdown]
# ## Clustering workflow
# 1. Choose features, create dataframe X
# 2. Elbow method to find k
# 3. Kmeans to create clusters
# 4. Add clusters to dataframe
# 5. Create centroids df for plotting
# 6. Visualize clusters
# 7. Statistical tests for logerror

# %%
train_scaled.head()
# Out:
#        bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet      fips  \
# 58664     0.166667    0.500000                      0.405443  0.000000
# 58627     0.250000    0.500000                      0.663551  0.297297
# 4891      0.166667    0.333333                      0.221550  1.000000
# 75490     0.333333    0.500000                      0.589335  0.297297
# 58604     0.166667    0.333333                      0.282298  0.000000
#
#        latitude  longitude  regionidcity  regionidcounty  regionidzip  \
# 58664  0.398569   0.703670      0.103354        1.000000     0.165932
# 58627  0.396694   0.852659      0.058616        0.000000     0.797357
# 4891   0.621453   0.164543      0.024574        0.426997     0.825991
# 75490  0.281951   0.775018      0.079603        0.000000     0.740088
# 58604  0.607553   0.555571      0.022785        1.000000     0.343612
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 58664                    0.037617           0.026046               0.013463
# 58627                    0.157100           0.159662               0.096607
# 4891                     0.142273           0.110767               0.050732
# 75490                    0.087539           0.053209               0.016661
# 58604                    0.215713           0.161734               0.067549
#
#        taxamount  logerror     acres       age  dollar_per_sqft  \
# 58664   0.066911  0.595731  0.107219  0.485294         0.024005
# 58627   0.268526  0.604554  0.160242  0.389706         0.066236
# 4891    0.166975  0.596289  0.088454  0.397059         0.142962
# 75490   0.115220  0.595744  0.097744  0.360294         0.040879
# 58604   0.271339  0.589734  0.104256  0.448529         0.182135
#
#        dollar_per_acre
# 58664         0.004116
# 58627         0.019877
# 4891          0.018590
# 75490         0.005563
# 58604         0.021119

# %% [markdown]
# ## Cluster 1: features_cluster
# - Bed Bath Sqft Taxvalue

# %%
# define features for clustering
X_train_feature_cluster = train_scaled[['bedroomcnt','bathroomcnt','calculatedfinishedsquarefeet','taxvaluedollarcnt']]

#repeat for validate and test
X_validate_feature_cluster = validate_scaled[['bedroomcnt','bathroomcnt','calculatedfinishedsquarefeet','taxvaluedollarcnt']]
X_test_feature_cluster = test_scaled[['bedroomcnt','bathroomcnt','calculatedfinishedsquarefeet','taxvaluedollarcnt']]

# %%
# Use the elbow method to consider a k for future clustering
viz.cluster1_elbow_for_k(X_train_feature_cluster)

# %%
# Visual representation of different K of clusters
viz.clusterwit_n_k(X_train_feature_cluster)

# %% [markdown]
# # K selected
# possible k = 4, 5 or 6
#
# We will be using k = 4

# %%
# define cluster object
kmeans = KMeans(n_clusters=5, random_state = 333)
# fit cluster object to features
kmeans.fit(X_train_feature_cluster)
# use the object
kmeans.predict(X_train_feature_cluster);

# %%
validate_scaled
# Out:
#        bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet      fips  \
# 70299     0.333333    0.500000                      0.587411  0.000000
# 42011     0.333333    0.666667                      0.820231  0.000000
# 5753      0.333333    0.666667                      0.668499  0.000000
# 49753     0.500000    0.666667                      0.849368  0.000000
# 76391     0.166667    0.166667                      0.316658  0.297297
# ...            ...         ...                           ...       ...
# 52809     0.166667    0.333333                      0.202859  0.000000
# 41693     0.250000    0.333333                      0.370808  0.297297
# 12368     0.000000    0.333333                      0.163551  0.000000
# 70336     0.166667    0.333333                      0.305113  0.297297
# 77133     0.500000    0.500000                      0.840847  0.000000
#
#        latitude  longitude  regionidcity  regionidcounty  regionidzip  \
# 70299  0.596911   0.451220      0.022785             1.0     0.298825
# 42011  0.539818   0.922739      0.069752             1.0     0.357562
# 5753   0.971393   0.693725      0.005198             1.0     0.980176
# 49753  0.568822   0.827447      0.085289             1.0     0.353891
# 76391  0.222061   0.964444      0.023614             0.0     0.744493
# ...         ...        ...           ...             ...          ...
# 52809  0.412822   0.685035      0.112630             1.0     0.104993
# 41693  0.364734   0.909686      0.033768             0.0     0.767254
# 12368  0.427856   0.711437      0.002328             1.0     0.087372
# 70336  0.297218   0.786516      0.054294             0.0     0.784875
# 77133  0.461465   0.577138      0.286342             1.0     0.040382
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 70299                    0.156148           0.120376               0.053888
# 42011                    0.424931           0.579006               0.414839
# 5753                     0.173858           0.101097               0.023204
# 49753                    0.581418           0.400880               0.135171
# 76391                    0.159067           0.318145               0.269943
# ...                           ...                ...                    ...
# 52809                    0.030025           0.027519               0.019143
# 41693                    0.213828           0.327757               0.251242
# 12368                    0.110267           0.194194               0.159643
# 70336                    0.061480           0.053348               0.030746
# 77133                    0.189864           0.113088               0.027842
#
#        taxamount  logerror     acres       age  dollar_per_sqft  \
# 70299   0.207498  0.578516  0.167757  0.382353         0.073159
# 42011   0.882648  0.587567  0.146492  0.661765         0.148672
# 5753    0.226339  0.596628  0.091972  0.102941         0.072834
# 49753   0.819958  0.592815  0.120336  0.036765         0.197197
# 76391   0.664120  0.593109  0.065800  0.213235         0.123205
# ...          ...       ...       ...       ...              ...
# 52809   0.079683  0.585258  0.138437  0.544118         0.032154
# 41693   0.466611  0.592277  0.107466  0.176471         0.146491
# 12368   0.321145  0.585510  0.093114  0.492647         0.135358
# 70336   0.126920  0.598343  0.108345  0.433824         0.049018
# 77133   0.218991  0.578672  0.158452  0.375000         0.064922
#
#        dollar_per_acre
# 70299         0.010607
# 42011         0.093118
# 5753          0.008205
# 49753         0.036757
# 76391         0.131020
# ...                ...
# 52809         0.004558
# 41693         0.076215
# 12368         0.055622
# 70336         0.009274
# 77133         0.005802
#
# [11223 rows x 18 columns]

# %%
# add cluster features to train and X_train df's
train_scaled['feature_cluster'] = kmeans.predict(X_train_feature_cluster)
validate_scaled['feature_cluster'] = kmeans.predict(X_validate_feature_cluster)
test_scaled['feature_cluster'] = kmeans.predict(X_test_feature_cluster)
X_train_feature_cluster['feature_cluster'] = kmeans.predict(X_train_feature_cluster)

# %%
# adjust column for plotting purposes
# train['feature_cluster'] = 'cluster_' + train.feature_cluster.astype(str)
# X_train['feature_cluster'] = 'cluster_' + X_train.feature_cluster.astype(str)

# %%
X_train_feature_cluster
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 58664    0.500000     0.166667                      0.405443
# 58627    0.500000     0.250000                      0.663551
# 4891     0.333333     0.166667                      0.221550
# 75490    0.500000     0.333333                      0.589335
# 58604    0.333333     0.166667                      0.282298
# ...           ...          ...                           ...
# 54280    0.333333     0.166667                      0.384827
# 19168    0.500000     0.166667                      0.398296
# 49013    0.333333     0.333333                      0.664101
# 62465    0.333333     0.000000                      0.216877
# 60389    0.500000     0.333333                      0.573392
#
#        taxvaluedollarcnt  feature_cluster
# 58664           0.026046                1
# 58627           0.159662                2
# 4891            0.110767                1
# 75490           0.053209                2
# 58604           0.161734                1
# ...                  ...              ...
# 54280           0.229971                4
# 19168           0.020561                1
# 49013           0.168289                2
# 62465           0.191185                0
# 60389           0.244624                2
#
# [26187 rows x 5 columns]

# %%
train.head()
# Out:
#        bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 58664          2.0         4.0                        1835.0  6037.0
# 58627          2.5         4.0                        2774.0  6059.0
# 4891           2.0         3.0                        1166.0  6111.0
# 75490          3.0         4.0                        2504.0  6059.0
# 58604          2.0         3.0                        1387.0  6037.0
#
#          latitude    longitude  regionidcity  regionidcounty  regionidzip  \
# 58664  33904380.0 -118136532.0       44116.0          3101.0      96208.0
# 58627  33901728.0 -117853081.0       26531.0          1286.0      97068.0
# 4891   34219641.0 -119162221.0       13150.0          2061.0      97107.0
# 75490  33739429.0 -118000792.0       34780.0          1286.0      96990.0
# 58604  34199981.0 -118418291.0       12447.0          3101.0      96450.0
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 58664                     36225.0            60433.0                24208.0
# 58627                    150328.0           323045.0               172717.0
# 4891                     136169.0           226946.0                90777.0
# 75490                     83899.0           113820.0                29921.0
# 58604                    206302.0           327117.0               120815.0
#
#        taxamount  logerror     acres   age  dollar_per_sqft  dollar_per_acre
# 58664    1049.48  0.009815  0.164922  67.0        19.741144    146784.587973
# 58627    4063.56  0.078906  0.243802  54.0        54.191781    708432.440678
# 4891     2545.40  0.014183  0.137006  55.0       116.783019    662574.752011
# 75490    1771.68  0.009918  0.150826  50.0        33.505990    198380.328767
# 58604    4105.62 -0.037152  0.160514  62.0       148.739726    752674.685355

# %%
X_train_feature_cluster.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 58664    0.500000     0.166667                      0.405443
# 58627    0.500000     0.250000                      0.663551
# 4891     0.333333     0.166667                      0.221550
# 75490    0.500000     0.333333                      0.589335
# 58604    0.333333     0.166667                      0.282298
#
#        taxvaluedollarcnt  feature_cluster
# 58664           0.026046                1
# 58627           0.159662                2
# 4891            0.110767                1
# 75490           0.053209                2
# 58604           0.161734                1

# %%
pd.DataFrame(kmeans.cluster_centers_)
# Out:
#           0         1         2         3
# 0  0.213717  0.026561  0.193343  0.122737
# 1  0.371129  0.171370  0.305795  0.114785
# 2  0.504088  0.292982  0.523800  0.177627
# 3  0.531831  0.398474  0.742975  0.394633
# 4  0.333253  0.200571  0.383800  0.334485

# %%
# def get_centroids(kmeans, cluster_vars, cluster_name):
#     # get the centroids for each distinct cluster...

#     centroid_col_names = ['centroid_' + i for i in cluster_vars]

#     centroid_df = pd.DataFrame(kmeans.cluster_centers_, 
#                                columns=centroid_col_names).reset_index().rename(columns={'index': cluster_name})

#     return centroid_df

# %%
X_train_feature_cluster.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 58664    0.500000     0.166667                      0.405443
# 58627    0.500000     0.250000                      0.663551
# 4891     0.333333     0.166667                      0.221550
# 75490    0.500000     0.333333                      0.589335
# 58604    0.333333     0.166667                      0.282298
#
#        taxvaluedollarcnt  feature_cluster
# 58664           0.026046                1
# 58627           0.159662                2
# 4891            0.110767                1
# 75490           0.053209                2
# 58604           0.161734                1

# %%
X_train_feature_cluster.loc[:, X_train_feature_cluster.columns != 'feature_cluster']
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 58664    0.500000     0.166667                      0.405443
# 58627    0.500000     0.250000                      0.663551
# 4891     0.333333     0.166667                      0.221550
# 75490    0.500000     0.333333                      0.589335
# 58604    0.333333     0.166667                      0.282298
# ...           ...          ...                           ...
# 54280    0.333333     0.166667                      0.384827
# 19168    0.500000     0.166667                      0.398296
# 49013    0.333333     0.333333                      0.664101
# 62465    0.333333     0.000000                      0.216877
# 60389    0.500000     0.333333                      0.573392
#
#        taxvaluedollarcnt
# 58664           0.026046
# 58627           0.159662
# 4891            0.110767
# 75490           0.053209
# 58604           0.161734
# ...                  ...
# 54280           0.229971
# 19168           0.020561
# 49013           0.168289
# 62465           0.191185
# 60389           0.244624
#
# [26187 rows x 4 columns]

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns = X_train_feature_cluster.loc[:, X_train_feature_cluster.columns != 'feature_cluster'].columns)

# %%
# visualize clusters with their centroids
viz.cluster1_centroid(X_train_feature_cluster, centroids)

# %%
# visualize clusters against bathroomscnt vs taxvaluedollarcnt

# %%
# visualize clusters against bathrooms vs taxvaluedollarcnt
viz.cluster_bathroom_vs_taxvalue(X_train_feature_cluster, centroids)

# %% [markdown]
# Cluster 1 = low taxvalue, low sqft, low bed/bath
#     Small houses with few bed/bath
#
# Cluster 2 = low-mid tax, low-mid sqft, low-mid bed/bath
#     Small houses with a couple bed/bath
#
# Cluster 3 = high taxvalue, high sqft, high bed/bath
#     Large houses with more bathrooms
#         MORE BATHS MORE RICH?
#
# Cluster 4 = average taxvalue, diverse sqft : bed/bath

# %% [markdown]
# ## Cluster 2: value_cluster
# - structuretax/taxvaluedollar/landtax/taxamount

# %%
train_scaled.index
# Out:
# Int64Index([58664, 58627,  4891, 75490, 58604, 28073,  1856, 71214, 16258,
#             33051,
#             ...
#             21180,  2051, 51788,  9946,  3970, 54280, 19168, 49013, 62465,
#             60389],
#            dtype='int64', length=26187)

# %%
# define features for clustering
X_train_value_cluster = train_scaled[['structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'taxamount']]

#repeat for validate and test
X_validate_value_cluster = validate_scaled[['structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'taxamount']]
X_test_value_cluster = test_scaled[['structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'taxamount']]

# %%
X_train_value_cluster
# Out:
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 58664                    0.037617           0.026046               0.013463
# 58627                    0.157100           0.159662               0.096607
# 4891                     0.142273           0.110767               0.050732
# 75490                    0.087539           0.053209               0.016661
# 58604                    0.215713           0.161734               0.067549
# ...                           ...                ...                    ...
# 54280                    0.128856           0.229971               0.189072
# 19168                    0.028281           0.020561               0.012419
# 49013                    0.248905           0.168289               0.057015
# 62465                    0.080314           0.191185               0.172346
# 60389                    0.269081           0.244624               0.130225
#
#        taxamount
# 58664   0.066911
# 58627   0.268526
# 4891    0.166975
# 75490   0.115220
# 58604   0.271339
# ...          ...
# 54280   0.401465
# 19168   0.059453
# 49013   0.309882
# 62465   0.323600
# 60389   0.366324
#
# [26187 rows x 4 columns]

# %%
# elbow method to find k in cluster 2
viz.cluster2_elbow_for_k(X_train_value_cluster)

# %% [markdown]
# k = 4

# %%
# define cluster object
kmeans = KMeans(n_clusters=4, random_state = 333)
# fit cluster object to features
kmeans.fit(X_train_value_cluster)
# use the object
kmeans.predict(X_train_value_cluster);

# %%
X_train_value_cluster
# Out:
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 58664                    0.037617           0.026046               0.013463
# 58627                    0.157100           0.159662               0.096607
# 4891                     0.142273           0.110767               0.050732
# 75490                    0.087539           0.053209               0.016661
# 58604                    0.215713           0.161734               0.067549
# ...                           ...                ...                    ...
# 54280                    0.128856           0.229971               0.189072
# 19168                    0.028281           0.020561               0.012419
# 49013                    0.248905           0.168289               0.057015
# 62465                    0.080314           0.191185               0.172346
# 60389                    0.269081           0.244624               0.130225
#
#        taxamount
# 58664   0.066911
# 58627   0.268526
# 4891    0.166975
# 75490   0.115220
# 58604   0.271339
# ...          ...
# 54280   0.401465
# 19168   0.059453
# 49013   0.309882
# 62465   0.323600
# 60389   0.366324
#
# [26187 rows x 4 columns]

# %%
# add cluster features to train and X_train df's
train_scaled['value_cluster'] = kmeans.predict(X_train_value_cluster)
validate_scaled['value_cluster'] = kmeans.predict(X_validate_value_cluster)
test_scaled['value_cluster'] = kmeans.predict(X_test_value_cluster)


X_train_value_cluster['value_cluster'] = kmeans.predict(X_train_value_cluster);

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns = X_train_value_cluster.loc[:, X_train_value_cluster.columns != 'value_cluster'].columns)

# %%
centroids
# Out:
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 0                    0.074188           0.062114               0.033597
# 1                    0.348623           0.493662               0.361729
# 2                    0.149573           0.179619               0.122591
# 3                    0.215970           0.309265               0.229749
#
#    taxamount
# 0   0.120841
# 1   0.767745
# 2   0.298791
# 3   0.489058

# %%
# visualize CLUSTER 2 structuretax/taxvaluedollar/landtax/taxamount
viz.cluster2_with_centroid(X_train_value_cluster, centroids)

# %% [markdown]
# ## Cluster 3: development_cluster
# - lat/long, age

# %%
X_train_development_cluster = train[['latitude','longitude','age']]
X_validate_development_cluster = validate[['latitude','longitude','age']]
X_test_development_cluster = test[['latitude','longitude','age']]

# %%
# cluster 3 elbow method to find k
viz.cluster3_elbow_for_k(X_train_value_cluster)

# %%
# define cluster object
kmeans = KMeans(n_clusters=5, random_state = 333)
# fit cluster object to features
kmeans.fit(X_train_development_cluster)
# use the object
kmeans.predict(X_train_development_cluster);

# %%
# add cluster features to train and X_train df's
train_scaled['development_cluster'] = kmeans.predict(X_train_development_cluster)
validate_scaled['development_cluster'] = kmeans.predict(X_validate_development_cluster)
test_scaled['development_cluster'] = kmeans.predict(X_test_development_cluster)

X_train_development_cluster['development_cluster'] = kmeans.predict(X_train_development_cluster);

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns = X_train_development_cluster.loc[:, X_train_development_cluster.columns != 'development_cluster'].columns)

# %%
# visualize cluster 3 lat/long, age
viz.cluster3_with_centroid(X_train_development_cluster, centroids)

# %% [markdown]
# # Statistical Tests

# %% [markdown]
# ### 1. Is logerror different between clusters based on house features?
# - Run anova test
#
# $H_{0}$: Means of the logerror between clusters are equal
#
# $H_{a}$ Means of the logerror between clusters are not equal

# %%
from scipy import stats
alpha = 0.5

# %%
f, p = stats.f_oneway(train_scaled[train_scaled.feature_cluster == 0].logerror,
                     train_scaled[train_scaled.feature_cluster == 1].logerror,
                     train_scaled[train_scaled.feature_cluster == 2].logerror,
                     train_scaled[train_scaled.feature_cluster == 3].logerror)

# %%
if p < alpha:
    print("We reject the null hypothesis")
else:
    print("We fail to reject the null hypothesis")
# Out:
# We reject the null hypothesis

# %% [markdown]
# #### The means are different, but is there a correlation between our cluster and logerror?

# %% [markdown]
# - pearsonr test
#
# $H_{0}$: There is no correlation between feature clusters and logerror
#
# $H_{a}$ There is a correlation between feature clusters and logerror

# %%
x = train_scaled.feature_cluster
y = train_scaled.logerror

corr, p = stats.pearsonr(x, y)

if p < alpha:
    print('We reject the null hypothesis')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis

# %% [markdown]
# #### There is a small correlation let's visualize it to double check

# %%
sns.relplot(data = train_scaled, x = 'feature_cluster', y = 'logerror')

# %% [markdown]
# ### 2. Is logerror different between clusters based on value and is there a correlation between the clusters and logerror?
#
# - Run anova test
#
# $H_{0}$: Means of the logerror between clusters are equal
#
# $H_{a}$ Means of the logerror between clusters are not equal

# %%
f, p = stats.f_oneway(train_scaled[train_scaled.value_cluster == 0].logerror,
                     train_scaled[train_scaled.value_cluster == 1].logerror,
                     train_scaled[train_scaled.value_cluster == 2].logerror,
                     train_scaled[train_scaled.value_cluster == 3].logerror)

# %%
if p < alpha:
    print("We reject the null hypothesis")
else:
    print("We fail to reject the null hypothesis")
# Out:
# We reject the null hypothesis

# %% [markdown]
# #### The means are different, is there a correlation?
#
# - pearsonr test
#
# $H_{0}$: There is no correlation between feature clusters and logerror
#
# $H_{a}$ There is a correlation between feature clusters and logerror

# %%
x = train_scaled.value_cluster
y = train_scaled.logerror

corr, p = stats.pearsonr(x, y)

if p < alpha:
    print('We reject the null hypothesis')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis

# %%
sns.relplot(data = train_scaled, x = 'value_cluster', y = 'logerror')

# %% [markdown]
# There is a correlation between clusters based on tax value and logerror, we can use this new feature in our modeling.

# %% [markdown]
# ### 3. Is logerror different between clusters based on location and age and is there a correlation between the clusters and logerror?
#
# - Run anova test
#
# $H_{0}$: Means of the logerror between clusters are equal
#
# $H_{a}$ Means of the logerror between clusters are not equal

# %%
f, p = stats.f_oneway(train_scaled[train_scaled.development_cluster == 0].logerror,
                     train_scaled[train_scaled.development_cluster == 1].logerror,
                     train_scaled[train_scaled.development_cluster == 2].logerror,
                     train_scaled[train_scaled.development_cluster == 3].logerror)

# %%
if p < alpha:
    print("We reject the null hypothesis")
else:
    print("We fail to reject the null hypothesis")
# Out:
# We reject the null hypothesis

# %% [markdown]
# #### The means are not different, is there a correlation?
#
# - pearsonr test
#
# $H_{0}$: There is no correlation between feature clusters and logerror
#
# $H_{a}$ There is a correlation between feature clusters and logerror

# %%
x = train_scaled.development_cluster
y = train_scaled.logerror

corr, p = stats.pearsonr(x, y)

if p < alpha:
    print('We reject the null hypothesis')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis

# %%
sns.relplot(data = train_scaled, x = 'development_cluster', y = 'logerror')

# %% [markdown]
# There is a correlation between clusters based on tax value and logerror, we can use this new feature in our modeling.

# %% [markdown]
# ### 4. Is there a correlation between bedroom count and logerror?
#
# - pearsonr test
#
# $H_{0}$: There is no correlation between bedroom count and logerror
#
# $H_{a}$ There is a correlation between bedroom count and logerror

# %%
x = train.bedroomcnt
y = train.logerror

corr, p = stats.pearsonr(x, y)

if p < alpha:
    print('We reject the null hypothesis')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis

# %% [markdown]
# #### There is a correlation between bedroom count and logerror
# Let's visualize

# %%
sns.relplot(data = train, x = 'bedroomcnt', y = 'logerror')

# %% [markdown]
# The log error is greater within the second quartile of the bedroomcnt

# %% [markdown]
# ### 5. Is there a correlation between bathroom count and logerror?
#
# - pearsonr test
#
# $H_{0}$: There is no correlation between bathroom count and logerror
#
# $H_{a}$ There is a correlation between bathroom count and logerror

# %%
x = train.bathroomcnt
y = train.logerror

corr, p = stats.pearsonr(x, y)

if p < alpha:
    print('We reject the null hypothesis')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis

# %% [markdown]
# #### There is a correlation between bathroom count and logerror

# %%
sns.relplot(data = train, x = 'bathroomcnt', y = 'logerror')

# %% [markdown]
# It looks like the first quartile has greater log error

# %% [markdown]
# ### 6. Is there a correlation between calculatedfinishedsquarefeet and logerror?
#
# - pearsonr test
#
# $H_{0}$: There is no correlation between finished square feet and logerror
#
# $H_{a}$ There is a correlation between finished square feet and logerror

# %%
x = train.calculatedfinishedsquarefeet
y = train.logerror

corr, p = stats.pearsonr(x, y)

if p < alpha:
    print('We reject the null hypothesis')
else:
    print('We fail to reject the null hypothesis')
# Out:
# We reject the null hypothesis

# %% [markdown]
# There is a correlation between finished square feet and logerror

# %%
sns.relplot(data = train, x = 'calculatedfinishedsquarefeet', y = 'logerror')

# %% [markdown]
# ## Distribution of our data

# %%
train_scaled.columns.to_list()
# Out:
# ['bathroomcnt',
#  'bedroomcnt',
#  'calculatedfinishedsquarefeet',
#  'fips',
#  'latitude',
#  'longitude',
#  'regionidcity',
#  'regionidcounty',
#  'regionidzip',
#  'structuretaxvaluedollarcnt',
#  'taxvaluedollarcnt',
#  'landtaxvaluedollarcnt',
#  'taxamount',
#  'logerror',
#  'acres',
#  'age',
#  'dollar_per_sqft',
#  'dollar_per_acre',
#  'feature_cluster',
#  'value_cluster',
#  'development_cluster']

# %%
# visulize shape of data
viz.shape(train_scaled)

# %% [markdown]
# ## Exploration Summary
#
# 1. Feature Engineering
#     - Features created
#         - Acres: lot sq ft / 43560
#         - dollar_per_sqft: structure tax value / finished sq ft
#         - dollar_per_acre: land tax value / acre
#         -
# 2. Clusters
#     - Our clusters have some correlation between logerror
#     - Cluster 1 will not be used for modeling
#     - Cluster 2 and 3 can be used for modeling
# 3. Driving Features
#     - Bed
#     - Bath
#     - Sq Ft
#     - Tax Value

# %% [markdown]
# # Modeling: Predicting logerror

# %%
#import linear regression modules
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures

#import evaluation metrics
from sklearn.metrics import mean_squared_error, explained_variance_score

# %%
X_train = train_scaled.drop(columns = 'logerror')
y_train = train.logerror
X_validate = validate_scaled.drop(columns = 'logerror')
y_validate = validate.logerror
X_test = test_scaled.drop(columns = 'logerror')
y_test = test.logerror

# %% [markdown]
# ## Baseline

# %%
# Create dataframes of the target for modeling purposes
y_train = pd.DataFrame(y_train)
y_validate = pd.DataFrame(y_validate)

# predict mean
pred_mean = y_train.logerror.mean()
y_train['baseline_pred_mean'] = pred_mean
y_validate['baseline_pred_mean'] = pred_mean

# RMSE of mean
rmse_train = mean_squared_error(y_train.logerror, y_train.baseline_pred_mean)**(1/2)
print("Train/In-Sample RMSE: ", round(rmse_train, 2))
# evs of mean
evs = explained_variance_score(y_train.logerror, y_train.baseline_pred_mean)
print('Explained Variance of Mean Baseline: ', round(evs,3))

# validate rmse
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.baseline_pred_mean)**(1/2)
print("Validate/Out-of-Sample RMSE: ", round(rmse_validate, 2))
# validate evs
evs = explained_variance_score(y_train.logerror, y_train.baseline_pred_mean)
print('Explained Variance of Mean Baseline: ', round(evs,3))
# Out:
# Train/In-Sample RMSE:  0.17
# Explained Variance of Mean Baseline:  0.0
# Validate/Out-of-Sample RMSE:  0.16
# Explained Variance of Mean Baseline:  0.0

# %% [markdown]
# ## Model 1: OLS

# %%
# Create model
lm = LinearRegression(normalize=True,)

# fit the model to training data.
lm.fit(X_train, y_train.logerror)

# predict train
y_train['logerror_pred_lm'] = lm.predict(X_train)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.logerror, y_train.logerror_pred_lm)**(1/2)

print("Training/In-Sample RMSE: ", rmse_train)
evs = explained_variance_score(y_train.logerror, y_train.logerror_pred_lm)
print('Train Explained Variance: ', round(evs,3))
# Out:
# Training/In-Sample RMSE:  0.16916482469448982
# Train Explained Variance:  0.005

# %% [markdown]
# ### Evaluate on Validate

# %%
# predict validate
y_validate['logerror_pred_lm'] = lm.predict(X_validate)

# evaluate rmse
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.logerror_pred_lm)**(1/2)

# evaluate evs
evs = explained_variance_score(y_validate.logerror, y_validate.logerror_pred_lm)
print("Validation/Out-of-Sample RMSE:", rmse_validate,'\nValidate Explained Variance: ', round(evs,3))
# Out:
# Validation/Out-of-Sample RMSE: 0.15907216837890897
# Validate Explained Variance:  0.005

# %% [markdown]
# ## Model 2: GLM

# %%
X_train.shape
# Out:
# (26187, 20)

# %%
y_train
# Out:
#        logerror  baseline_pred_mean  logerror_pred_lm
# 58664  0.009815            0.017804          0.034318
# 58627  0.078906            0.017804          0.030258
# 4891   0.014183            0.017804          0.009886
# 75490  0.009918            0.017804          0.040161
# 58604 -0.037152            0.017804          0.003050
# ...         ...                 ...               ...
# 54280 -0.064756            0.017804          0.013895
# 19168  0.021380            0.017804          0.035223
# 49013  0.039788            0.017804          0.019688
# 62465  0.022888            0.017804          0.013852
# 60389 -0.097962            0.017804          0.031178
#
# [26187 rows x 3 columns]

# %%
# create the model object
glm = TweedieRegressor(power = 0, alpha=0.5)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
glm.fit(X_train, y_train.logerror)

# predict train
y_train['logerror_pred_glm'] = glm.predict(X_train)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.logerror, y_train.logerror_pred_glm)**(1/2)

# predict validate
y_validate['logerror_pred_glm'] = glm.predict(X_validate)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.logerror_pred_glm)**(1/2)

print("RMSE for GLM using Tweedie, power=1 & alpha=0\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)

evs = explained_variance_score(y_train.logerror, y_train.logerror_pred_glm)
print('Train Explained Variance = ', round(evs,3))
evs = explained_variance_score(y_validate.logerror, y_validate.logerror_pred_glm)
print('Validate Explained Variance = ', round(evs,3))
# Out:
# RMSE for GLM using Tweedie, power=1 & alpha=0
# Training/In-Sample:  0.1694257450529027
# Validation/Out-of-Sample:  0.1593159493988983
# Train Explained Variance =  0.002
# Validate Explained Variance =  0.002

# %% [markdown]
# ## Model 3: LassoLars

# %%
# create the model object
lars = LassoLars(alpha=10)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lars.fit(X_train, y_train.logerror)

# predict train
y_train['logerror_pred_lars'] = lars.predict(X_train)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.logerror, y_train.logerror_pred_lars)**(1/2)

# predict validate
y_validate['logerror_pred_lars'] = lars.predict(X_validate)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.logerror_pred_lars)**(1/2)

print("RMSE for Lasso + Lars\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)

evs = explained_variance_score(y_train.logerror, y_train.logerror_pred_lars)
print('Train Explained Variance = ', round(evs,3))
evs = explained_variance_score(y_validate.logerror, y_validate.logerror_pred_lars)
print('Validate Explained Variance = ', round(evs,3))
# Out:
# RMSE for Lasso + Lars
# Training/In-Sample:  0.1695546484055886
# Validation/Out-of-Sample:  0.1594845483479586
# Train Explained Variance =  0.0
# Validate Explained Variance =  0.0

# %% [markdown]
# ## Model 4: Polynomial

# %%
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled
X_train_degree2 = pf.fit_transform(X_train)

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate)
X_test_degree2 = pf.transform(X_test)

# %%
# create the model object
lm2 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lm2.fit(X_train_degree2, y_train.logerror)

# predict train
y_train['logerror_pred_lm2'] = lm2.predict(X_train_degree2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.logerror, y_train.logerror_pred_lm2)**(1/2)

# predict validate
y_validate['logerror_pred_lm2'] = lm2.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.logerror_pred_lm2)**(1/2)

print("RMSE for Polynomial Model, degrees=2\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)

evs = explained_variance_score(y_train.logerror, y_train.logerror_pred_lm2)
print('Train Explained Variance = ', round(evs,3))
evs = explained_variance_score(y_validate.logerror, y_validate.logerror_pred_lm2)
print('Validate Explained Variance = ', round(evs,3))
# Out:
# RMSE for Polynomial Model, degrees=2
# Training/In-Sample:  0.1681860662264187
# Validation/Out-of-Sample:  0.1597135613534361
# Train Explained Variance =  0.016
# Validate Explained Variance =  -0.003

# %% [markdown]
# # Model Comparison

# %%
# All models compared
# plot to visualize actual vs predicted.
viz.model_compare(y_validate)

# %% [markdown]
# # Compares RMSE for all models

# %%
# Compares the RMSE of all models vs Logerror and mean base line prediction
viz.RMSE_all_models(y_validate)

# %% [markdown]
# ## Evaluate on Test

# %%
y_test = pd.DataFrame(y_test)

# target log error usning mean 
y_test['logerror_pred_mean'] = y_test.logerror.mean()

# predict on test
y_test['logerror_pred_lm'] = lm.predict(X_test)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.logerror, y_test.logerror_pred_lm)**(1/2)

print("RMSE for OLS Model using LinearRegression\nOut-of-Sample Performance: ", rmse_test)

evs = explained_variance_score(y_test.logerror, y_test.logerror_pred_lm)
print('Test Explained Variance = ', round(evs,3))
# Out:
# RMSE for OLS Model using LinearRegression
# Out-of-Sample Performance:  0.17140105333631372
# Test Explained Variance =  0.0

# %%
# compare actual Logerror against Linear Regression model
viz.best_model_vs_logerror(y_test)

# %%
y_test.sample()
# Out:
#        logerror  logerror_pred_mean  logerror_pred_lm
# 77087  0.171809            0.017101          0.016025

# %%
viz.actal_logerror_vs_predicted_OLS(y_test)

# %%
y_validate.sample()
# Out:
#        logerror  baseline_pred_mean  logerror_pred_lm  logerror_pred_glm  \
# 72048  0.011157            0.017804          0.007919           0.018385
#
#        logerror_pred_lars  logerror_pred_lm2
# 72048            0.017804           0.010106

# %%
y_test.sample()
# Out:
#        logerror  logerror_pred_mean  logerror_pred_lm
# 38981  2.042549            0.017101          0.018132

# %%
# Visual for residual error
viz.resiudal_error(y_test)

# %%
df
# Out:
#        bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0              3.5         4.0                        3100.0  6059.0
# 1              1.0         2.0                        1465.0  6111.0
# 2              2.0         3.0                        1243.0  6059.0
# 3              3.0         4.0                        2376.0  6037.0
# 6              3.0         4.0                        2962.0  6037.0
# ...            ...         ...                           ...     ...
# 77568          2.0         4.0                        1633.0  6037.0
# 77570          2.0         2.0                        1286.0  6037.0
# 77571          2.0         4.0                        1612.0  6111.0
# 77572          1.0         3.0                        1032.0  6037.0
# 77573          2.0         3.0                        1762.0  6037.0
#
#          latitude    longitude  regionidcity  regionidcounty  regionidzip  \
# 0      33634931.0 -117869207.0       53571.0          1286.0      96978.0
# 1      34449266.0 -119281531.0       13091.0          2061.0      97099.0
# 2      33886168.0 -117823170.0       21412.0          1286.0      97078.0
# 3      34245180.0 -118240722.0      396551.0          3101.0      96330.0
# 6      34145202.0 -118179824.0       47019.0          3101.0      96293.0
# ...           ...          ...           ...             ...          ...
# 77568  33870815.0 -118070858.0       30267.0          3101.0      96204.0
# 77570  34245368.0 -118282383.0       12447.0          3101.0      96284.0
# 77571  34300140.0 -118706327.0       27110.0          2061.0      97116.0
# 77572  34040895.0 -118038169.0       36502.0          3101.0      96480.0
# 77573  33937685.0 -117996709.0       14634.0          3101.0      96171.0
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 0                        485713.0          1023282.0               537569.0
# 1                         88000.0           464000.0               376000.0
# 2                         85289.0           564778.0               479489.0
# 3                        108918.0           145143.0                36225.0
# 6                        276684.0           773303.0               496619.0
# ...                           ...                ...                    ...
# 77568                    125466.0           346534.0               221068.0
# 77570                     70917.0           354621.0               283704.0
# 77571                     50683.0            67205.0                16522.0
# 77572                     32797.0            49546.0                16749.0
# 77573                    140000.0           522000.0               382000.0
#
#        taxamount  logerror     acres   age  dollar_per_sqft  dollar_per_acre
# 0       11013.72  0.025595  0.103444  19.0       156.681613     5.196739e+06
# 1        5672.48  0.055619  0.290335  50.0        60.068259     1.295055e+06
# 2        6488.30  0.005383  0.193572  55.0        68.615447     2.477057e+06
# 3        1777.51 -0.103410  0.299311  47.0        45.840909     1.210278e+05
# 6        9516.26 -0.001011  1.446281  67.0        93.411209     3.433766e+05
# ...          ...       ...       ...   ...              ...              ...
# 77568    4175.08  0.001082  0.106290  55.0        76.831598     2.079854e+06
# 77570    4478.43  0.020615  1.088269  77.0        55.145412     2.606929e+05
# 77571    1107.48  0.013209  0.277893  53.0        31.441067     5.945463e+04
# 77572     876.43  0.037129  0.116483  63.0        31.780039     1.437892e+05
# 77573    6317.15  0.007204  0.145707  62.0        79.455165     2.621698e+06
#
# [46763 rows x 18 columns]
